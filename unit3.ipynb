# %% [markdown]
# //standard deviation ()//
# the std tells typical distance of data points from the mean
# low std=data is consistent and bunched near the center
# high std=data is erratic and spread far from the centre

# %% [markdown]
# the z-score: the outlier detector
# -> to check mathematically if a point is in rare zone.
# if |z|>3 the point is in the rare zone

# %% [markdown]
# CORRELATION IS NOT CAUSATION
#
# just because two variables move together doesn't mean one causes other.
# ->coincindence
# ->confounding variables
