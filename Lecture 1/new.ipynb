# %%
# hello

print("Hello world")
# Out:
# Hello world

# %% [markdown]
# Task 2.1 --

# %%
import numpy as np

# %%
mat=np.array([[1,2,3],[4,56,6]]);
print(mat);
# Out:
# [[ 1  2  3]
#  [ 4 56  6]]

# %%
arr=np.array([100,200,300]);
arr=arr*2;
print(arr);
# Out:
# [200 400 600]

# %%
print(arr*mat);
# Out:
# [[  200   800  1800]
#  [  800 22400  3600]]

# %%
print(np.sqrt(arr*mat));
# Out:
# [[ 14.14213562  28.28427125  42.42640687]
#  [ 28.28427125 149.66629547  60.        ]]

# %% [markdown]
# task3

# %%
sales = np.array([
    [50, 65, 70, 60],   
    [80, 75, 90, 85],   
    [40, 55, 60, 65],   
        
])

print(sales)

print(sales[0]) #print first row

print(sales[:, 0:2])
# Out:
# [[50 65 70 60]
#  [80 75 90 85]
#  [40 55 60 65]]
# [50 65 70 60]
# [[50 65]
#  [80 75]
#  [40 55]]

# %% [markdown]
# task4

# %%
print(sales.reshape(2,6));
# Out:
# [[50 65 70 60 80 75]
#  [90 85 40 55 60 65]]

# %%
print(sales.reshape(12));
# Out:
# [50 65 70 60 80 75 90 85 40 55 60 65]

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(1,100,10);
print(x);
# Out:
# [  1.  12.  23.  34.  45.  56.  67.  78.  89. 100.]

# %% [markdown]
# task5

# %%
arr=np.random.randint(1,20,12);
print(arr.reshape(3,4));
# Out:
# [[12  8 17  2]
#  [ 9  5  7 14]
#  [13  7  5 17]]

# %%
print(np.random.randint(1,100,5));
# Out:
# [60 38 61 88 62]
