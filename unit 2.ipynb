# %% [markdown]
# INTRODUCTION TO PANDAS

# %%
import pandas as pd
import numpy as nu

# %%
 s = pd.Series([10, 20, 30, 40])
print(s)
 data = {
    "a": 10,
    "b": 20,
    "c": 30
}

s = pd.Series(data)

print(s)
data = {
    "Name": ["Aman", "krish", "karan"],
    "Age": [22, 23, 21],
    "Marks": [85, 90, 88]
}
 print(data)
 type(data)
 marks = pd.DataFrame(data)
 print(marks)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
# a    10
# b    20
# c    30
# dtype: int64
# {'Name': ['Aman', 'krish', 'karan'], 'Age': [22, 23, 21], 'Marks': [85, 90, 88]}
#     Name  Age  Marks
# 0   Aman   22     85
# 1  krish   23     90
# 2  karan   21     88

# %%
#we can also add custom index in python
marks=pd.DataFrame(data,
                   index=["student1","student2","student3"])

# %%
print(marks)
# Out:
#            Name  Age  Marks
# student1   Aman   22     85
# student2  krish   23     90
# student3  karan   21     88

# %%
marks.set_index("Name", inplace=True)
print(marks)
# Out:
#        Age  Marks
# Name
# Aman    22     85
# krish   23     90
# karan   21     88

# %%
df=pd.DataFrame({
    "Name":["abx","xos","afs"],
    "Age":[12,21,33],
    "Marks":[88,99,98]
})
print(df)
# Out:
#   Name  Age  Marks
# 0  abx   12     88
# 1  xos   21     99
# 2  afs   33     98

# %%
df.head()
# Out:
#   Name  Age  Marks
# 0  abx   12     88
# 1  xos   21     99
# 2  afs   33     98

# %%
df.tail()
# Out:
#   Name  Age  Marks
# 0  abx   12     88
# 1  xos   21     99
# 2  afs   33     98

# %%
df[df["Marks"]>85]
# Out:
#   Name  Age  Marks
# 0  abx   12     88
# 1  xos   21     99
# 2  afs   33     98

# %%
df["Name"]
# Out:
# 0    abx
# 1    xos
# 2    afs
# Name: Name, dtype: object

# %%
df[(df["Age"]>21) & (df["Marks"]>85)]
# Out:
#   Name  Age  Marks
# 2  afs   33     98

# %%
df.sort_values("Marks")
# Out:
#   Name  Age  Marks
# 0  abx   12     88
# 2  afs   33     98
# 1  xos   21     99

# %%
df.sort_values("Marks",ascending=False)
# Out:
#   Name  Age  Marks
# 1  xos   21     99
# 2  afs   33     98
# 0  abx   12     88

# %%
df["Age"].value_counts()
# Out:
# Age
# 12    1
# 21    1
# 33    1
# Name: count, dtype: int64

# %%
import pandas as pd

# %% [markdown]
# Handling missing values

# %%
#updating the dataset with null values

df=pd.DataFrame({
    "Name":["Aman","Saurav","Karan","subham",None,"Sameer"],
    "Age":[22,23,None,22,25,26],
    "Marks":[85,None,88,90,66,None]
})

df
# Out:
#      Name   Age  Marks
# 0    Aman  22.0   85.0
# 1  Saurav  23.0    NaN
# 2   Karan   NaN   88.0
# 3  subham  22.0   90.0
# 4    None  25.0   66.0
# 5  Sameer  26.0    NaN

# %%
df.isnull()
# Out:
#     Name    Age  Marks
# 0  False  False  False
# 1  False  False   True
# 2  False   True  False
# 3  False  False  False
# 4   True  False  False
# 5  False  False   True

# %%
df.isnull().sum()
# Out:
# Name     1
# Age      1
# Marks    2
# dtype: int64

# %%
df.dropna()
# Out:
#      Name   Age  Marks
# 0    Aman  22.0   85.0
# 3  subham  22.0   90.0

# %%
print(df)
# Out:
#      Name   Age  Marks
# 0    Aman  22.0   85.0
# 1  Saurav  23.0    NaN
# 2   Karan   NaN   88.0
# 3  subham  22.0   90.0
# 4    None  25.0   66.0
# 5  Sameer  26.0    NaN

# %%
cleaned_data=df.dropna()
cleaned_data
# Out:
#      Name   Age  Marks
# 0    Aman  22.0   85.0
# 3  subham  22.0   90.0
